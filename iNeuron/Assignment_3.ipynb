# %% [markdown]
# 1. Why are functions advantageous to have in your programs?

# %% [markdown]
# Functions allow you to reuse code, make your programs modular, and simplify complex operations by breaking them down into smaller tasks. This improves readability, reduces redundancy, and makes debugging easier.

# %% [markdown]
# 2. When does the code in a function run: when it’s specified or when it’s called?

# %% [markdown]
# The code in a function runs when the function is called, not when it's defined.

# %% [markdown]
# 3. What statement creates a function?

# %% [markdown]
# The `def` statement is used to create a function in Python.

# %% [markdown]
# 4. What is the difference between a function and a function call?

# %% [markdown]
# A function is the block of code defined using `def`, while a function call is when you invoke or execute the function to perform its operations.

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# There is one global scope in a Python program. However, there can be multiple local scopes, as each function call creates a new local scope.

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# Variables in a local scope are destroyed when the function call returns. Their values do not persist after the function exits.

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# A return value is the output of a function that is passed back to the caller when the function completes. Yes, a return value can be part of an expression, allowing the result of the function to be used in further operations.

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# If a function does not explicitly return a value, it returns `None`.

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?

# %% [markdown]
# You can use the `global` keyword inside the function to refer to a global variable.

# %% [markdown]
# 10. What is the data type of None?

# %% [markdown]
# The data type of `None` is `NoneType`.

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# It attempts to import a module named areallyourpetsnamederic. If the module doesn't exist, it raises an ImportError.

# %% [markdown]
# 12. If you had a bacon() function in a spam module, how would you call it after importing spam?

# %% [markdown]
# You would call it as spam.bacon().

# %% [markdown]
# 13. What can you do to save a program from crashing if it encounters an error?

# %% [markdown]
# You can use exception handling with try and except blocks to catch and handle errors gracefully.

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# The try clause is used to test a block of code for errors. The except clause is used to handle the error if one occurs during the execution of the try block.

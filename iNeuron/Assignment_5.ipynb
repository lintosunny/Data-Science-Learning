# %% [markdown]
# 1. What does an empty dictionary's code look like?

# %% [markdown]
# An empty dictionary is represented as {}.

# %% [markdown]
# 2. What is the value of a dictionary with the key 'foo' and the value 42?

# %% [markdown]
# The dictionary would look like {'foo': 42}.

# %% [markdown]
# 3. What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# A dictionary stores key-value pairs and is unordered, while a list stores items in an ordered sequence and is indexed by position.

# %% [markdown]
# 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %% [markdown]
# You will get a KeyError because 'foo' is not a key in the dictionary.

# %% [markdown]
# 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?

# %% [markdown]
# There is no difference. Both expressions check if 'cat' is a key in the dictionary spam.

# %% [markdown]
# 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

# %% [markdown]
# 'cat' in spam checks if 'cat' is a key in the dictionary, while 'cat' in spam.values() checks if 'cat' is a value in the dictionary.

# %% [markdown]
# 7. What is a shortcut for the following code?
#
# if &#39;color&#39; not in spam:
#
# spam[&#39;color&#39;] = &#39;black&#39;

# %%
spam.setdefault('color', 'black')

# %% [markdown]
# 8. How do you "pretty print" dictionary values using which module and function?

# %%
import pprint
pprint.pprint(dictionary)
